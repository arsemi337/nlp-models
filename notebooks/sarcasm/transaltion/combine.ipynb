# %%
import pandas as pd

# %%
good_0_6000 = pd.read_json('../../../data/translated/sarcasm/good_0_6000.json')
good_0_6000
# Out:
#       is_sarcastic                                           headline  \
# 0                1  thirtysomething scientists unveil doomsday clo...
# 1                0  dem rep. totally nails why congress is falling...
# 2                0  eat your veggies: 9 deliciously different recipes
# 3                1  inclement weather prevents liar from getting t...
# 4                1  mother comes pretty close to using word 'strea...
# ...            ...                                                ...
# 5995             1  mueller poses as fox news host to coax rudy gi...
# 5996             0  jimmy kimmel suggests the perfect vacation spo...
# 5997             1  box with cooking instructions immediately retr...
# 5998             0                         how to connect with others
# 5999             0  when it comes to pregnancy discrimination, equ...
#
#                                            article_link  \
# 0     https://www.theonion.com/thirtysomething-scien...
# ...

# %%
good_6000_10000 = pd.read_json('../../../data/translated/sarcasm/good_6000_10000.json')
good_6000_10000
# Out:
#       is_sarcastic                                           headline  \
# 0                0  what was left of the moderate republican party...
# 1                0    how my latino family does christmas differently
# 2                1  biblical scholars find evidence church covered...
# 3                0  miles teller doing ok after bronco flips over ...
# 4                0                 get chic this upcoming fall season
# ...            ...                                                ...
# 3995             0            listen to america: a huffpost road trip
# 3996             0  exclusive: ginger minj's 'white christmas' vid...
# 3997             0  a pragmatist's guide to coming out stronger af...
# 3998             1  'grand theft auto v' missions to focus largely...
# 3999             0                a test for chronic fatigue syndrome
#
#                                            article_link  \
# 0     https://www.huffingtonpost.com/entry/rubio-tru...
# ...

# %%
good_10000_12000 = pd.read_json('../../../data/translated/sarcasm/good_10000_12000.json')
good_10000_12000
# Out:
#       is_sarcastic                                           headline  \
# 0                0  everything you need to know about the bad demo...
# 1                1  retired couple realizes dream of buying camper...
# 2                0  the horrible awkwardness and angst of being a ...
# 3                1        area dad needs more time with museum plaque
# 4                0  donald trump jr.'s thanksgiving conversation s...
# ...            ...                                                ...
# 1995             1      best-laid plans of mice mostly cheese-related
# 1996             0  ken burns implores stanford graduates to belie...
# 1997             0  computer science in vietnam: counting down to ...
# 1998             1  obama waiting for perfect moment to walk by wh...
# 1999             1  babysitter enters third hour of negotiations t...
#
#                                            article_link  \
# 0     https://www.huffingtonpost.com/entry/low-democ...
# ...

# %%
good_12000_15000 = pd.read_json('../../../data/translated/sarcasm/good_12000_15000.json')
good_12000_15000
# Out:
#       is_sarcastic                                           headline  \
# 0                0  republican sen. gardner torches sessions over ...
# 1                0  house bipartisanship throws up pitifully weak ...
# 2                0  black and blue: on being black, female and dep...
# 3                1  this the fuck harness sex shop worker has at home
# 4                0  thousands march on national mall to demand pue...
# ...            ...                                                ...
# 2995             0  ava duvernay on women and minorities breaking ...
# 2996             1  ted cruz provides detailed response to moderat...
# 2997             0  'night of a thousand judys' is a pride month e...
# 2998             0           the most important first step to success
# 2999             0  arsons at 6 black churches in st. louis area a...
#
#                                            article_link  \
# 0     https://www.huffingtonpost.com/entry/republica...
# ...

# %%
good_15000_17000 = pd.read_json('../../../data/translated/sarcasm/good_15000_17000.json')
good_15000_17000
# Out:
#       is_sarcastic                                           headline  \
# 0                1  gop leaders move goalposts on opposing trump t...
# 1                1  djimon hounsou to play every african in the world
# 2                0                             who's afraid to think?
# 3                0  google doodle celebrates planetary discovery i...
# 4                0  a message to my serbian friends in response to...
# ...            ...                                                ...
# 1995             1  parents clinging to lone religious element of ...
# 1996             0    is a college degree really the best investment?
# 1997             1  wife dropping hints she ready to have second h...
# 1998             0  divorcing parents: 10 questions to ask before ...
# 1999             1  last beer in six pack drunk with plastic rings...
#
#                                            article_link  \
# 0     https://politics.theonion.com/gop-leaders-move...
# ...

# %%
good_17000_20000 = pd.read_json('../../../data/translated/sarcasm/good_17000_20000.json')
good_17000_20000
# Out:
#       is_sarcastic                                           headline  \
# 0                1  hmo targets blacks with 'rapping good' health ...
# 1                0  joy reid's hacking claims look increasingly un...
# 2                1       faa assures public: air travel 'pretty safe'
# 3                0  santa claus tells stephen colbert why he voted...
# 4                1  clooney scouting locations for darfur-based ro...
# ...            ...                                                ...
# 2995             1             house of blues opens drive-thru window
# 2996             0  making sure internet explorer doesn't replace ...
# 2997             0  boehner does damage control: benghazi probe wa...
# 2998             1  report: mom going to need you to pitch in arou...
# 2999             0  freedom caucus closing in on deal to rewrite h...
#
#                                            article_link  \
# 0     https://www.theonion.com/hmo-targets-blacks-wi...
# ...

# %%
good_20000_24000 = pd.read_json('../../../data/translated/sarcasm/good_20000_24000.json')
good_20000_24000
# Out:
#       is_sarcastic                                           headline  \
# 0                0  i wrote speeches for vice president biden. her...
# 1                1  fabled lost city of gold finally discovered of...
# 2                0  amy schumer plays a revealing game of 'would y...
# 3                0           is this black parenting magazine racist?
# 4                0  opening wider and diving deeper into the immea...
# ...            ...                                                ...
# 3995             0                       no bern-ing love for hillary
# 3996             0  bernie sanders is closer than ever to catching...
# 3997             1  night of uninterrupted deep sleep really throw...
# 3998             1  laid-off hostess employee forced to look for c...
# 3999             0              here comes another massive media deal
#
#                                            article_link  \
# 0     https://www.huffingtonpost.com/entry/speeches-...
# ...

# %%
good_24000_40000 = pd.read_json('../../../data/translated/sarcasm/good_24000_40000.json')
good_24000_40000
# Out:
#       is_sarcastic                                           headline  \
# 0                1             obama asks biden not to stand so close
# 1                1  judge restricts roger stone's travel between f...
# 2                0  new technologies give government ample means t...
# 3                0  national review writer: ben carson 'more authe...
# 4                0   who admits it botched response to ebola outbreak
# ...            ...                                                ...
# 4614             1       jews to celebrate rosh hashasha or something
# 4615             1  internal affairs investigator disappointed con...
# 4616             0  the most beautiful acceptance speech this week...
# 4617             1  mars probe destroyed by orbiting spielberg-gat...
# 4618             1                 dad clarifies this not a food stop
#
#                                            article_link  \
# 0     https://politics.theonion.com/obama-asks-biden...
# ...

# %%
frames = [good_0_6000, good_6000_10000, good_10000_12000, good_12000_15000, good_15000_17000, good_17000_20000, good_20000_24000, good_24000_40000]
len(frames)
# Out:
# 8

# %%
result = pd.concat(frames)
result
# Out:
#       is_sarcastic                                           headline  \
# 0                1  thirtysomething scientists unveil doomsday clo...
# 1                0  dem rep. totally nails why congress is falling...
# 2                0  eat your veggies: 9 deliciously different recipes
# 3                1  inclement weather prevents liar from getting t...
# 4                1  mother comes pretty close to using word 'strea...
# ...            ...                                                ...
# 4614             1       jews to celebrate rosh hashasha or something
# 4615             1  internal affairs investigator disappointed con...
# 4616             0  the most beautiful acceptance speech this week...
# 4617             1  mars probe destroyed by orbiting spielberg-gat...
# 4618             1                 dad clarifies this not a food stop
#
#                                            article_link  \
# 0     https://www.theonion.com/thirtysomething-scien...
# ...

# %%
result.reset_index(drop=True, inplace=True)
result
# Out:
#        is_sarcastic                                           headline  \
# 0                 1  thirtysomething scientists unveil doomsday clo...
# 1                 0  dem rep. totally nails why congress is falling...
# 2                 0  eat your veggies: 9 deliciously different recipes
# 3                 1  inclement weather prevents liar from getting t...
# 4                 1  mother comes pretty close to using word 'strea...
# ...             ...                                                ...
# 28614             1       jews to celebrate rosh hashasha or something
# 28615             1  internal affairs investigator disappointed con...
# 28616             0  the most beautiful acceptance speech this week...
# 28617             1  mars probe destroyed by orbiting spielberg-gat...
# 28618             1                 dad clarifies this not a food stop
#
#                                             article_link  \
# ...

# %%
result.to_json(r'../../../data/translated/sarcasm/sarcasm_headlines_dataset_pl.json')

# %%
read_df = pd.read_json('../../../data/translated/sarcasm/sarcasm_headlines_dataset_pl.json')
read_df
# Out:
#        is_sarcastic                                           headline  \
# 0                 1  thirtysomething scientists unveil doomsday clo...
# 1                 0  dem rep. totally nails why congress is falling...
# 2                 0  eat your veggies: 9 deliciously different recipes
# 3                 1  inclement weather prevents liar from getting t...
# 4                 1  mother comes pretty close to using word 'strea...
# ...             ...                                                ...
# 28614             1       jews to celebrate rosh hashasha or something
# 28615             1  internal affairs investigator disappointed con...
# 28616             0  the most beautiful acceptance speech this week...
# 28617             1  mars probe destroyed by orbiting spielberg-gat...
# 28618             1                 dad clarifies this not a food stop
#
#                                             article_link  \
# ...
